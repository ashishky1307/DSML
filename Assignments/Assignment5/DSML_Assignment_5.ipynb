# %%
sample=pd.read_csv("/content/Mall_Customers.csv")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sample.describe
# Out:
# <bound method NDFrame.describe of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
# scatter plot
plt.scatter(sample["CustomerID"], sample["Age"])
plt.xlabel("customer id")
plt.ylabel("Age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# line graph


plt.plot(sample["Annual Income (k$)"],sample["Age"])
plt.xlabel("annual income")
plt.ylabel("Age")
plt.show()

# %%
# bar graph
plt.bar(sample["Genre"],sample["Spending Score (1-100)"])
#y=sample["CustomerId"]
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.title("MALL")
# Out:
# Text(0.5, 1.0, 'MALL')

# %%
plt.hist(sample["CustomerID"],sample["Annual Income (k$)"])
plt.xlabel("customer id")
plt.ylabel("Annual income")
plt.show()

# %%
#pie graph

#y=("male", "female")
plt.pie(sample["Age"])
plt.show()

# %%
plt.stem(sample["CustomerID"],sample["Genre"], orientation="horizontal",bottom=7)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.kdeplot(data=sample, x="CustomerID")
# Out:
# <Axes: xlabel='CustomerID', ylabel='Density'>

# %%
sns.heatmap(sample.corr())
# Out:
# <ipython-input-13-2b7fd58c0b51>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sample.corr())
# <Axes: >

# %%
sns.boxplot(x="Genre",y="Age", data=sample)
# Out:
# <Axes: xlabel='Genre', ylabel='Age'>
