# %%
import numpy as np
import pandas as pd

# %%
sample=pd.read_csv("/content/admission.csv")

# %%
# describe the dataset and format of colomn
sample.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
sample.info()
# for column datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
#indexing data according to column
sample[["GRE Score","CGPA"]]
# Out:
#      GRE Score  CGPA
# 0          337  9.65
# 1          324  8.87
# 2          316  8.00
# 3          322  8.67
# 4          314  8.21
# ..         ...   ...
# 495        332  9.02
# 496        337  9.87
# 497        330  9.56
# 498        312  8.43
# 499        327  9.04
#
# [500 rows x 2 columns]

# %%
#indexing data according to row
sample.loc[0:5]
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# 5         1              0.90

# %%
# sort dataset
sample.sort_values("GRE Score")
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 377         378        290          100                  1  1.5   2.0  7.56
# 117         118        290          104                  4  2.0   2.5  7.46
# 168         169        293           97                  2  2.0   4.0  7.80
# 79           80        294           93                  1  1.5   2.0  7.36
# 272         273        294           95                  1  1.5   1.5  7.64
# ..          ...        ...          ...                ...  ...   ...   ...
# 81           82        340          120                  4  5.0   5.0  9.50
# 84           85        340          115                  5  4.5   4.5  9.45
# 143         144        340          120                  4  4.5   4.0  9.92
# 384         385        340          113                  4  5.0   5.0  9.74
# 429         430        340          115                  5  5.0   4.5  9.06
#
#      Research  Chance of Admit
# ...

# %%
# counting unique values
sample.value_counts()
# Out:
# Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Chance of Admit
# 1           337        118          4                  4.5  4.5   9.65  1         0.92                1
# 330         297        96           2                  2.5  1.5   7.89  0         0.43                1
# 343         308        106          3                  3.0  3.0   8.24  0         0.58                1
# 342         326        110          3                  3.5  3.5   8.76  1         0.79                1
# 341         312        107          3                  3.0  3.0   8.46  1         0.75                1
#                                                                                                      ..
# 162         298        99           1                  1.5  3.0   7.46  0         0.53                1
# 161         315        103          1                  1.5  2.0   7.86  0         0.57                1
# ...

# %%
# convert  variable datatype
sample.CGPA.astype(int)
# Out:
# 0      9
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 495    9
# 496    9
# 497    9
# 498    8
# 499    9
# Name: CGPA, Length: 500, dtype: int64

# %%
sample.fillna(1)# put 1 where value is true
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
sample.isnull()# identify missing value
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False  False  False
# 3         False      False        False              False  False  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 495       False      False        False              False  False  False
# 496       False      False        False              False  False  False
# 497       False      False        False              False  False  False
# 498       False      False        False              False  False  False
# 499       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False             False
# ...
